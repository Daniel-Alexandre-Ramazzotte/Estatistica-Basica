# %%
import sqlite3
  conn =
  sqlite3.connect('banco_questoes/questoes.db')
  cursor = conn.cursor()
  cursor.execute("SELECT * FROM questions LIMIT 5")
  for row in cursor.fetchall():
      print(row)
  conn.close()
